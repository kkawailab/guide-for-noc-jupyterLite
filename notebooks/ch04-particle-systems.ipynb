# %% [markdown]
# # Chapter 04 — Particle Systems
#
# - Particles encapsulate position, velocity, lifespan; emitters spawn many instances.
# - Forces (gravity, wind) applied uniformly create cohesive effects like smoke or rain.
# - Recycling dead particles keeps simulations efficient.
# - Use randomness for variation but constrain with distributions for believable results.
#
# Try: Tune gravity or velocity spread to morph between fountain and smoke-like motion.

# %%
import randomclass Vector:    def __init__(self, x=0.0, y=0.0):        self.x, self.y = float(x), float(y)    def __add__(self, other):        return Vector(self.x + other.x, self.y + other.y)    def __sub__(self, other):        return Vector(self.x - other.x, self.y - other.y)    def __mul__(self, k):        return Vector(self.x * k, self.y * k)    __rmul__ = __mul__    def __repr__(self):        return f"Vector({self.x:.2f}, {self.y:.2f})"class Particle:    def __init__(self, origin):        self.pos = Vector(*origin)        self.vel = Vector(random.uniform(-1, 1), random.uniform(0, 2))        self.lifespan = 80    def update(self, gravity=Vector(0, -0.05)):        self.vel += gravity        self.pos += self.vel        self.lifespan -= 1    def alive(self):        return self.lifespan > 0particles = [Particle((0, 0)) for _ in range(5)]for frame in range(8):    for p in particles:        p.update()    particles = [p for p in particles if p.alive()]    if frame % 2 == 0:        particles.append(Particle((0, 0)))    print(f"frame {frame}: count={len(particles)} positions={[p.pos for p in particles[:3]]}")
