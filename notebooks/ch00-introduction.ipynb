# %% [markdown]
# # Chapter 00 — Introduction
#
# - Computational systems mimic natural processes by combining randomness with rules.
# - Deterministic chaos arises from simple iterative functions (e.g., logistic map).
# - Noise functions (Perlin/simplex) create organic variation; randomness alone looks harsh.
# - Discrete time steps plus stateful objects are the basis for simulations.
#
# Try: Modify steps or the move set to explore biased or constrained walks.

# %%
import random# Simple random walker in 2D gridrandom.seed(1)steps = 25x = y = 0path = [(x, y)]for _ in range(steps):    dx, dy = random.choice([(1,0),(-1,0),(0,1),(0,-1)])    x += dx    y += dy    path.append((x, y))print("Visited points:")for i, p in enumerate(path):    print(f"{i:02d}: {p}")
